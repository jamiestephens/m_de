# %%
import plotly
import plotly.express as px
import yfinance as yf

# %%
currencies = ['JPY=X','GBPUSD=X','AUDUSD=X','NZDUSD=X','CNY=X','HKD=X','SGD=X','INR=X','MXN=X','PHP=X','THB=X','MYR=X','ZAR=X','RUB=X']


df_agg = []

for i in currencies:
    j = i[0:3]
    df = yf.download(tickers = i,period='1y',interval='1h')
    df = df.reset_index()
    del df['Volume']
    del df['Adj Close']
    df_name = f"df1{j}"
    df_names.append(df_name)
    globals()[df_name]=df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df1JPY.to_csv('test.csv')

# %%
for i, df in enumerate(df_names):
    dataframe = df
    print(dataframe)
    value_1 = dataframe['Open'].iloc[0]
    value_2 = enum_df['Close'].iloc[-1]
    #df_changes = pd.DataFrame(columns=["Currency", "Total Change","Percent Change"])
    #df_changes = df_changes.append({
        #"Currency":enum_df,
        #"Total Change":value_2-value_1,
        #"Percent Change":((value_2-value_1)/abs(value_1))*100},ignore_index=True)
# Out:
# df-JPY
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-b429d4111f70> in <module>
#       2     dataframe = df
#       3     print(dataframe)
# ----> 4     value_1 = dataframe['Open'].iloc[0]
#       5     value_2 = enum_df['Close'].iloc[-1]
#       6     #df_changes = pd.DataFrame(columns=["Currency", "Total Change","Percent Change"])
#
# TypeError: string indices must be integers

# %%
for k, v in list(globals().items()):
    if k[0:3] == "df-":
        print(k)
        print(type(k))
# Out:
# df-JPY
# <class 'str'>
# df-GBP
# <class 'str'>
# df-AUD
# <class 'str'>
# df-NZD
# <class 'str'>
# df-CNY
# <class 'str'>
# df-HKD
# <class 'str'>
# df-SGD
# <class 'str'>
# df-INR
# <class 'str'>
# df-MXN
# <class 'str'>
# df-PHP
# <class 'str'>
# df-THB
# <class 'str'>
# df-MYR
# <class 'str'>
# df-ZAR
# <class 'str'>
# df-RUB
# <class 'str'>

# %%
if 'Datetime' in df_JPY:
    x_axis = 'Datetime'
else:
    x_axis = 'Date'
    
    
fig = px.line(df_JPY, x=x_axis, y="Percent Change", title='JPY to USD')

# %%
fig.show()
# Out:
# <div>                            <div id="8a769918-5661-4df3-96cd-8ae79af584ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a769918-5661-4df3-96cd-8ae79af584ff")) {                    Plotly.newPlot(                        "8a769918-5661-4df3-96cd-8ae79af584ff",                        [{"hovertemplate": "Date=%{x}<br>Percent Change=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2021-01-19T00:00:00", "2021-01-20T00:00:00", "2021-01-21T00:00:00", "2021-01-22T00:00:00", "2021-01-25T00:00:00", "2021-01-26T00:00:00", "2021-01-27T00:00:00", "2021-01-28T00:00:00", "2021-01-29T00:00:00", "2021-02-01T00:00:00", "2021-0
# ...
